# %%
import scipy.io as sio
import numpy as np
img = sio.loadmat('../data/matlab/fibrosis/1.mat')
img = np.array(img['img'])

# %%
from matplotlib import pyplot as plt
plt.imshow(img)
plt.show()
img.shape
# Out:
# (71, 81, 3)

# %%
img = sio.loadmat('../data/matlab/healthy/1.mat')
img = np.array(img['img'])
plt.imshow(img)
plt.show()
img.shape
# Out:
# (89, 86, 3)

# %%
img = sio.loadmat('../data/matlab/ground_glass/1.mat')
img = np.array(img['img'])
plt.imshow(img)
plt.show()
img.shape
# Out:
# (27, 39, 3)

# %%
img = sio.loadmat('../data/matlab/emphysema/1.mat')
img = np.array(img['img'])
plt.imshow(img)
plt.show()
img.shape
# Out:
# (76, 72, 3)

# %%
img = sio.loadmat('../data/matlab/micronodules/1.mat')
img = np.array(img['img'])
plt.imshow(img)
plt.show()
img.shape
# Out:
# (157, 111, 3)

# %%
img = sio.loadmat('../data/matlab/fibrosis/3.mat')
img = np.array(img['img'])
plt.imshow(img)
plt.show()
img.shape
# Out:
# (71, 81, 3)
